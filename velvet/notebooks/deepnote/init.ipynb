# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting dframcy
#   Downloading dframcy-0.1.5.tar.gz (39 kB)
# Collecting jsondiff
#   Downloading jsondiff-1.2.0.tar.gz (8.0 kB)
# Requirement already satisfied: scipy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from dframcy->-r ./requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: numpy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from dframcy->-r ./requirements.txt (line 1)) (1.19.5)
# Requirement already satisfied: click in /shared-libs/python3.7/py/lib/python3.7/site-packages (from dframcy->-r ./requirements.txt (line 1)) (7.1.2)
# Requirement already satisfied: wasabi in /shared-libs/python3.7/py/lib/python3.7/site-packages (from dframcy->-r ./requirements.txt (line 1)) (0.8.2)
# Requirement already satisfied: pytest in /shared-libs/python3.7/py/lib/python3.7/site-packages (from dframcy->-r ./requirements.txt (line 1)) (6.2.2)
# Collecting pytest-cov
#   Downloading pytest_cov-2.11.1-py2.py3-none-any.whl (20 kB)
# Collecting tox-travis
#   Downloading tox_travis-0.12-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: pandas in /shared-libs/python3.7/py/lib/python3.7/site-packages (from dframcy->-r ./requirements.txt (line 1)) (1.2.1)
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Collecting spacy==2.2.0
#   Downloading spacy-2.2.0-cp37-cp37m-manylinux1_x86_64.whl (10.2 MB)
# Requirement already satisfied: importlib-metadata>=0.12; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pytest->dframcy->-r ./requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: packaging in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pytest->dframcy->-r ./requirements.txt (line 1)) (20.9)
# Requirement already satisfied: toml in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pytest->dframcy->-r ./requirements.txt (line 1)) (0.10.2)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pytest->dframcy->-r ./requirements.txt (line 1)) (0.13.1)
# Requirement already satisfied: attrs>=19.2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pytest->dframcy->-r ./requirements.txt (line 1)) (20.3.0)
# Requirement already satisfied: py>=1.8.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pytest->dframcy->-r ./requirements.txt (line 1)) (1.10.0)
# Requirement already satisfied: iniconfig in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pytest->dframcy->-r ./requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: coverage>=5.2.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pytest-cov->dframcy->-r ./requirements.txt (line 1)) (5.4)
# Collecting tox>=2.0
#   Downloading tox-3.21.4-py2.py3-none-any.whl (84 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pandas->dframcy->-r ./requirements.txt (line 1)) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas->dframcy->-r ./requirements.txt (line 1)) (2021.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy==2.2.0->dframcy->-r ./requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy==2.2.0->dframcy->-r ./requirements.txt (line 1)) (2.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy==2.2.0->dframcy->-r ./requirements.txt (line 1)) (2.25.1)
# Collecting srsly<1.1.0,>=0.1.0
#   Downloading srsly-1.0.5-cp37-cp37m-manylinux2014_x86_64.whl (184 kB)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy==2.2.0->dframcy->-r ./requirements.txt (line 1)) (3.0.5)
# Collecting plac<1.0.0,>=0.9.6
#   Downloading plac-0.9.6-py2.py3-none-any.whl (20 kB)
# Collecting blis<0.5.0,>=0.4.0
#   Downloading blis-0.4.1-cp37-cp37m-manylinux1_x86_64.whl (3.7 MB)
# Collecting thinc<7.2.0,>=7.1.1
#   Downloading thinc-7.1.1-cp37-cp37m-manylinux1_x86_64.whl (2.1 MB)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata>=0.12; python_version < "3.8"->pytest->dframcy->-r ./requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata>=0.12; python_version < "3.8"->pytest->dframcy->-r ./requirements.txt (line 1)) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from packaging->pytest->dframcy->-r ./requirements.txt (line 1)) (2.4.7)
# Requirement already satisfied: six>=1.14.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from tox>=2.0->tox-travis->dframcy->-r ./requirements.txt (line 1)) (1.15.0)
# Collecting virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0
#   Downloading virtualenv-20.4.2-py2.py3-none-any.whl (7.2 MB)
# Collecting filelock>=3.0.0
#   Downloading filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.0->dframcy->-r ./requirements.txt (line 1)) (1.26.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.0->dframcy->-r ./requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.0->dframcy->-r ./requirements.txt (line 1)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.0->dframcy->-r ./requirements.txt (line 1)) (2020.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from thinc<7.2.0,>=7.1.1->spacy==2.2.0->dframcy->-r ./requirements.txt (line 1)) (4.56.0)
# Collecting distlib<1,>=0.3.1
#   Downloading distlib-0.3.1-py2.py3-none-any.whl (335 kB)
# Collecting appdirs<2,>=1.4.3
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Building wheels for collected packages: dframcy, jsondiff
#   Building wheel for dframcy (setup.py): started
#   Building wheel for dframcy (setup.py): finished with status 'done'
#   Created wheel for dframcy: filename=dframcy-0.1.5-py3-none-any.whl size=23346 sha256=1f15349cf1351610bb14c401c205270722a126549982e417cff0a6d7188e2c98
#   Stored in directory: /root/.cache/pip/wheels/af/fe/b2/54abd100cbd641ab72f32409d005cbcb5f2a47b2bd60054b90
#   Building wheel for jsondiff (setup.py): started
#   Building wheel for jsondiff (setup.py): finished with status 'done'
#   Created wheel for jsondiff: filename=jsondiff-1.2.0-py3-none-any.whl size=6539 sha256=ecd70e9e8401b4e9fa841667d52d9711ff4d11bbb8d8cbdc9282af59ece73d34
#   Stored in directory: /root/.cache/pip/wheels/13/19/b3/9065e430a7cd8215f03a27af9d3352b8b4833a22204856c1bd
# Successfully built dframcy jsondiff
# Installing collected packages: jsondiff, pytest-cov, filelock, distlib, appdirs, virtualenv, tox, tox-travis, xlrd, srsly, plac, blis, thinc, spacy, dframcy
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.0
#     Not uninstalling srsly at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'srsly'. No files were found to uninstall.
#   Attempting uninstall: blis
#     Found existing installation: blis 0.7.4
#     Not uninstalling blis at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'blis'. No files were found to uninstall.
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.0.1
#     Not uninstalling thinc at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'thinc'. No files were found to uninstall.
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.0.1
#     Not uninstalling spacy at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'spacy'. No files were found to uninstall.
# Successfully installed appdirs-1.4.4 blis-0.4.1 dframcy-0.1.5 distlib-0.3.1 filelock-3.0.12 jsondiff-1.2.0 plac-0.9.6 pytest-cov-2.11.1 spacy-2.2.0 srsly-1.0.5 thinc-7.1.1 tox-3.21.4 tox-travis-0.12 virtualenv-20.4.2 xlrd-2.0.1
# WARNING: You are using pip version 20.1.1; however, version 21.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=67ebbc4a-1b4b-449c-a00e-722787d292e7' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
